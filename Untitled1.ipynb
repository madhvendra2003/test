# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df= pd.read_csv('./scipy-2019-pandas-master/data/output.csv')

# %%
df
# Out:
#       Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 0         44.0  0.797417 -0.958091      NaN       NaN     158.0  1.490148
# 1         47.0  0.026838 -0.244178        D       NaN       NaN  2.151535
# 2         64.0  0.199990 -1.014799        B       0.0     474.0  1.410613
# 3         67.0  0.474124  0.448040        B       NaN     166.0  0.635091
# 4          NaN  0.598516  0.087839      NaN       0.0       NaN  0.392104
# ...        ...       ...       ...      ...       ...       ...       ...
# 4995       NaN  0.819440  0.415931        C       0.0       NaN  1.765590
# 4996       NaN  0.032140 -1.445420        C       1.0       NaN  0.806246
# 4997      92.0  0.263300  0.986722        C       NaN      78.0  1.326853
# 4998      91.0  0.640986 -1.199847        A       0.0      51.0  0.312256
# 4999       NaN  0.901570  1.836382      NaN       0.0       NaN  2.087461
#
#       Feature8  Feature9  Feature10  Feature11 Feature12  Feature13  \
# ...

# %%
df.iloc[0]
# Out:
# Feature1          44.0
# Feature2      0.797417
# Feature3     -0.958091
# Feature4           NaN
# Feature5           NaN
# Feature6         158.0
# Feature7      1.490148
# Feature8      5.166124
# Feature9      2.277942
# Feature10          NaN
# Feature11            5
# Feature12            X
# Feature13            1
# Feature14    Category1
# Feature15      Option4
# Feature16     8.824345
# Feature17     11.71113
# Feature18          Yes
# Feature19          Low
# Feature20          NaN
# Name: 0, dtype: object

# %%
sns.displot(df.Feature1)

# %%
df_melt=df.melt()

# %%
df_melt
# Out:
#         variable       value
# 0       Feature1        44.0
# 1       Feature1        47.0
# 2       Feature1        64.0
# 3       Feature1        67.0
# 4       Feature1         NaN
# ...          ...         ...
# 99995  Feature20         NaN
# 99996  Feature20         NaN
# 99997  Feature20         NaN
# 99998  Feature20  some other
# 99999  Feature20  some other
#
# [100000 rows x 2 columns]

# %%
dfn=df.fillna(0)

# %%
df
# Out:
#       Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 0         44.0  0.797417 -0.958091      NaN       NaN     158.0  1.490148
# 1         47.0  0.026838 -0.244178        D       NaN       NaN  2.151535
# 2         64.0  0.199990 -1.014799        B       0.0     474.0  1.410613
# 3         67.0  0.474124  0.448040        B       NaN     166.0  0.635091
# 4          NaN  0.598516  0.087839      NaN       0.0       NaN  0.392104
# ...        ...       ...       ...      ...       ...       ...       ...
# 4995       NaN  0.819440  0.415931        C       0.0       NaN  1.765590
# 4996       NaN  0.032140 -1.445420        C       1.0       NaN  0.806246
# 4997      92.0  0.263300  0.986722        C       NaN      78.0  1.326853
# 4998      91.0  0.640986 -1.199847        A       0.0      51.0  0.312256
# 4999       NaN  0.901570  1.836382      NaN       0.0       NaN  2.087461
#
#       Feature8  Feature9  Feature10  Feature11 Feature12  Feature13  \
# ...

# %%
dfn
# Out:
#       Feature1  Feature2  Feature3 Feature4  Feature5  Feature6  Feature7  \
# 0         44.0  0.797417 -0.958091        0       0.0     158.0  1.490148
# 1         47.0  0.026838 -0.244178        D       0.0       0.0  2.151535
# 2         64.0  0.199990 -1.014799        B       0.0     474.0  1.410613
# 3         67.0  0.474124  0.448040        B       0.0     166.0  0.635091
# 4          0.0  0.598516  0.087839        0       0.0       0.0  0.392104
# ...        ...       ...       ...      ...       ...       ...       ...
# 4995       0.0  0.819440  0.415931        C       0.0       0.0  1.765590
# 4996       0.0  0.032140 -1.445420        C       1.0       0.0  0.806246
# 4997      92.0  0.263300  0.986722        C       0.0      78.0  1.326853
# 4998      91.0  0.640986 -1.199847        A       0.0      51.0  0.312256
# 4999       0.0  0.901570  1.836382        0       0.0       0.0  2.087461
#
#       Feature8  Feature9  Feature10  Feature11 Feature12  Feature13  \
# ...

# %%
# here isna()give the boolean value that is there nan or not isna.sum()gives the number of nan value
nan = (df.isna().sum() / len(df)) * 100

nan
tf=pd.DataFrame(nan)

tf
# Out:
#                0
# Feature1   54.08
# Feature2    0.00
# Feature3    0.00
# Feature4   37.36
# Feature5   40.64
# Feature6   39.68
# Feature7    0.00
# Feature8    2.02
# Feature9    0.00
# Feature10  56.72
# Feature11   0.00
# Feature12   0.00
# Feature13   0.00
# Feature14   0.00
# Feature15   0.00
# Feature16  40.12
# Feature17   0.00
# Feature18   0.00
# Feature19   5.90
# Feature20  34.66

# %%
tf = tf.rename(columns={0: 'percentage'})

# %%
tf['features']=['Feature1','Feature2','Feature3','Feature4','Feature5','Feature6','Feature7','Feature8','Feature9','Feature10',
               'Feature11','Feature12','Feature13','Feature14','Feature15','Feature16','Feature17','Feature18','Feature19','Feature20']

# %%
plt.pie(tf.percentage, labels=tf.features)
# Out:
# ([<matplotlib.patches.Wedge at 0x108b8904eb0>,
# ...
#  [Text(0.9400820314097831, 0.5711792837808947, 'Feature1'),
#   Text(0.5068258650537169, 0.9762825116289606, 'Feature2'),
#   Text(0.5068258650537169, 0.9762825116289606, 'Feature3'),
#   Text(0.11163791840995496, 1.0943203256693592, 'Feature4'),
#   Text(-0.6966247544022574, 0.8513013282933339, 'Feature5'),
#   Text(-1.0969812181676784, 0.08143836311810777, 'Feature6'),
#   Text(-1.04188905448583, -0.35279909033701257, 'Feature7'),
#   Text(-1.0344781328485761, -0.3739719142637908, 'Feature8'),
#   Text(-1.0266369963503335, -0.39498921216251653, 'Feature9'),
#   Text(-0.6488435637420753, -0.888257862217095, 'Feature10'),
#   Text(-0.0640412365288026, -1.0981341994600944, 'Feature11'),
#   Text(-0.0640412365288026, -1.0981341994600944, 'Feature12'),
#   Text(-0.0640412365288026, -1.0981341994600944, 'Feature13'),
#   Text(-0.0640412365288026, -1.0981341994600944, 'Feature14'),
# ...
